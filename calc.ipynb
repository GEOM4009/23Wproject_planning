# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
"""
# Import modules
from tkinter import *
from util import *
import argparse
import os

os.environ["USE_PYGEOS"] = "0"
import geopandas as gpd


# Global Variables
run_tests = False
verbose = True

default_crs = 0
planning_unit = 0  # gpd.GeoDataFrame()
planning_layers = []  # list(gpd.GeoDataFrame())


def getArgs() -> argparse.ArgumentParser:
    """
    Adds command line arguments to the program.

    Returns
    -------
    argparse.ArgumentParser
        Contains passed command line arguments.

    """

    # create parser
    parser = argparse.ArgumentParser()
    # add arguments here
    return parser.parse_args()


def validate_crs(crs: any, target_crs: str) -> bool:
    pass


def create_planning_unit(
    hex_size: float = None,
    grid_size: float = None,
    pos: tuple[float, float] = None,
) -> gpd.geoseries:
    pass


def select_planning_units() -> list[int]:


    # ask for input()
    # 1 Interactive map
    # 2 csv #do we want gui for this, easily done with Tkinter
    # 3 shp/gpgk file #do we want gui for this, easily done with Tkinter
    # 4 User Input
    # if 1:
    #     #display map with planning units and get input from user
    # elif 2:
    #     # read in csv of puids
    # elif 3:
    #     # read in and determine overlaps to generate list
    # elif 4:
    # ask user to enter puids (loop, or space seperated list)
    # validate
    # return puid_list
    pass


def select_planning_layers_to_load() -> list():
    # get user input()
    # while loop to load files manually
    # or profide
    # dir to load all files (include file type filter options)
    # or single or list of space seperated file paths

    # do we want gui for this, easily done with Tkinter
    return


def load_planning_layers() -> bool:
    # gpd.read_file()
    pass


def query_planning_layers() -> list[gpd.GeoDataFrame]:
    # get input()
    # show list or groups?
    # area selection on map?
    # probably easiest with gui here also???
    pass





# -> list of PUID, CFID tuples
def to_marxan_format() -> list[tuple[float, float]]:
    pass


def marxan_format_to_csv(arr: list[tuple[float, float]] = None) -> bool:
    return True


def main():
    """
    Parameters
    ----------

    Returns
    -------
    int
        0 for success, -1 for error
    """
    # selection = ''

    # while selection != "q":
    #     selection = input(
    #     '''
    #     1 Planning Unit Grid
    #     2 csv #do we want gui for this, easily done with Tkinter
    #     3 shp/gpgk file #do we want gui for this, easily done with Tkinter
    #     q QUIT
    #     '''
    #     )
    #     selection = selection.casefold()
    #     if selection == 'q':
    #         print("Goodbye")
    #     elif selection == "1":
    #         sub_select = input(
    #         '''
    #         1 Generate grid (manual)
    #         2 Generate grid (interactive)
    #         2 View on map
    #         '''
    #         )
    #         sub_select = sub_select.casefold()
    #         if sub_select == '1':

    #             ws = Tk()
    #             ws.title('Python Guides')
    #             # ws.geometry('400x300')
    #             # ws.config(bg='#446644')

    #             def getSelected():
    #                 countries = []
    #                 cname = lb.curselection()
    #                 for i in cname:
    #                     op = lb.get(i)
    #                     countries.append(op)
    #                 for val in countries:
    #                     print(val)
    #                 ws.destroy()

    #             frame = Frame(ws)
    #             frame.pack()

    #             lb = Listbox(frame, selectmode="multiple")
    #             lb.pack(side=LEFT)

    #             sb = Scrollbar(frame, orient=VERTICAL)
    #             sb.pack(side=RIGHT, fill=Y)

    #             lb.configure(yscrollcommand=sb.set)
    #             sb.config(command=lb.yview)
    #             lb.insert(0, 'red')
    #             lb.insert(1, 'green')
    #             lb.insert(2, 'yellow')
    #             lb.insert(3, 'blue')
    #             lb.insert(0, 'red')
    #             lb.insert(1, 'green')
    #             lb.insert(2, 'yellow')
    #             lb.insert(3, 'blue')
    #             lb.insert(0, 'red')
    #             lb.insert(1, 'green')
    #             lb.insert(2, 'yellow')
    #             lb.insert(3, 'blue')
    #             lb.insert(0, 'red')
    #             lb.insert(1, 'green')
    #             lb.insert(2, 'yellow')
    #             lb.insert(3, 'blue')

    #             Button(ws, text='Show Selected', command=getSelected).pack(pady=20)
    #             ws.lift()
    #             ws.attributes('-topmost',True)
    #             ws.after_idle(ws.attributes,'-topmost',False)
    #             ws.mainloop()

                # hexagon_size = float(input("Hexagon Size (m): "))
                # grid_size = float(input("Grid Size (km): "))
                # ancor_point = str(input("Grid anchor point: "))
                # grid_lat = float(input("Latitude of grid anchor point (dd): "))
                # grid_lon = float(input("Longitude of grid anchor point (dd): "))


    # get arguments from argparser
    args = getArgs()
    # extract and validate args here for clarity

    # Create a planning unit hexagonal grid with user input on hexagon size and grid size and position.
    create_planning_unit()

    # Take input on which planning unit(s) the proponent project will occupy
    select_planning_units()

    # Select planning layers to load
    select_planning_layers_to_load()

    # Load planning layers
    load_planning_layers()

    # Query for relevant planning features to use in the analysis
    query_planning_layers()

    # For each project PUID, calculate the area of overlap with the each conservation feature (CF) from the
    # planning layer and record this in a csv - a sparse matrix of PUID (rows) vs CFID (cols) with overlap
    # area as values.
    calc_overlap()

    # Reorganize the file so it can be ingested by Marxan
    to_marxan_format()

    # save to csv
    marxan_format_to_csv()

# %%
hexFile=r'.\data\PreliminaryFiles\PreliminaryFiles\PlanUnit.shp'
cfsFile=r'.\data\PreliminaryFiles\PreliminaryFiles\SelectedLayers.shp'
hexfile = hexFile.replace("\\",'/')
cfsFile = cfsFile.replace("\\",'/')

hex = gpd.read_file(hexFile)
cfs = gpd.read_file(cfsFile)

# %%
hex.plot(figsize=(8,8))
# Out:
# <AxesSubplot: >

# %%
cfs.plot(figsize=(8, 8))
# Out:
# <AxesSubplot: >

# %%
hex.crs

# %%
cfs.crs

# %%
cfs = cfs.to_crs(hex.crs)

# %%
cfs = cfs[cfs["CLASS_TYPE"] == "Narwhal Calving"]

# %%
cfs
# Out:
#                               CLASS_TYPE                       GROUP_   ID  \
# 0  Kitikmeot Community Areas of Interest  Community Areas of Interest  402
#
#                                                 NAME    Shape_Leng  \
# 0  Community Areas of Interest: Marine Areas adja...  2.293955e+06
#
#      Shape_Le_1    Shape_Area  \
# 0  2.293955e+06  5.117131e+10
#
#                                             geometry
# 0  POLYGON Z ((123625.435 3577509.660 0.000, 1433...

# %%
intersection = gpd.overlay(
    hex,
    cfs,
    how="intersection",
)

# %%
intersection.plot(figsize=(10, 10))
# Out:
# <AxesSubplot: >

# %%
intersection.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   GRID_ID       31 non-null     object
#  1   Shape_Leng_1  31 non-null     float64
#  2   Shape_Area_1  31 non-null     float64
#  3   CLASS_TYPE    31 non-null     object
#  4   GROUP_        31 non-null     object
#  5   ID            31 non-null     int64
#  6   NAME          31 non-null     object
#  7   Shape_Leng_2  31 non-null     float64
#  8   Shape_Le_1    31 non-null     float64
#  9   Shape_Area_2  31 non-null     float64
#  10  geometry      31 non-null     geometry
# dtypes: float64(5), geometry(1), int64(1), object(4)
# memory usage: 2.8+ KB

# %%
intersection["area"] = intersection.area

# %%
for index, row in intersection.iterrows():
    print(str(row['GRID_ID'])+',', str(row['ID'])+',', '{:.0f}'.format(row['area']))
    
sparse_matrix = []
# Out:
# JH-323, 402, 1229909
# JJ-323, 402, 9010255
# JK-323, 402, 645397
# JL-323, 402, 17196818
# JM-323, 402, 2096922
# JF-322, 402, 2302454
# JG-322, 402, 2048955
# JH-322, 402, 24653714
# JI-322, 402, 19343134
# JJ-322, 402, 25000000
# JK-322, 402, 24975941
# JL-322, 402, 25000000
# JM-322, 402, 25000000
# JF-321, 402, 773460
# JG-321, 402, 24458929
# JH-321, 402, 25000000
# JI-321, 402, 25000000
# JJ-321, 402, 25000000
# JK-321, 402, 25000000
# JL-321, 402, 25000000
# JM-321, 402, 25000000
# JG-320, 402, 6815361
# JH-320, 402, 9973037
# JI-320, 402, 25000000
# JJ-320, 402, 25000000
# JK-320, 402, 25000000
# JL-320, 402, 25000000
# JM-320, 402, 25000000
# JI-319, 402, 7822754
# JK-319, 402, 23370162
# JM-319, 402, 25000000
